# %%
square = ['0', '1', '2', '3', '4', '5', '6', '7', '8']

def board():
    print("\n Tic Tac Toe Game \n")
    print("\t" +square[0] + ' ' + square[1] + ' ' + square[2] + '\n')
    print("\t" +square[3] + ' ' + square[4] + ' ' + square[5] + '\n')
    print("\t" +square[6] + ' ' + square[7] + ' ' + square[8] + '\n')

# board()

# %%
def checkWin():
    result = 0
    
    if((square[0] == square[1]) and (square[1] == square[2])):
        result = 1
    elif((square[3] == square[4]) and (square[4] == square[5])):
        result = 1
    elif((square[6] == square[7]) and (square[7] == square[8])):
        result = 1
    elif((square[0] == square[3]) and (square[3] == square[6])):
        result = 1
    elif((square[1] == square[4]) and (square[4] == square[7])):
        result = 1
    elif((square[2] == square[5]) and (square[5] == square[8])):
        result = 1
    elif((square[0] == square[4]) and (square[4] == square[8])):
        result = 1
    elif((square[2] == square[4]) and (square[4] == square[6])):
        result = 1
    elif(square[0] != '0' and square[1] != '1' and square[2] != '2' and square[3] != '3' and square[4] != '4' and 
         square[5] != '5' and square[6] != '6' and square[7] != '7' and square[8] != '8'):
        result = 0
    else:
        result = -1
    
    return result

# %%
player = 1
i = 0
choice = 0
mark = "O"
flag = 0
board()

while flag == 0:
    print("Player Number ", player)
    choice = int(input("Enter the choice : "))
    
    if player == 1:
        mark = 'O'
    else:
        mark = 'X'
    
    if (choice == 0) and (square[0] == '0'):
        square[0] = mark
    elif (choice == 1) and (square[1] == '1'):
        square[1] = mark
    elif (choice == 2) and (square[2] == '2'):
        square[2] = mark
    elif (choice == 3) and (square[3] == '3'):
        square[3] = mark
    elif (choice == 4) and (square[4] == '4'):
        square[4] = mark
    elif (choice == 5) and (square[5] == '5'):
        square[5] = mark
    elif (choice == 6) and (square[6] == '6'):
        square[6] = mark
    elif (choice == 7) and (square[7] == '7'):
        square[7] = mark
    elif (choice == 8) and (square[8] == '8'):
        square[8] = mark
    elif (choice < 0) or (choice > 8):
        print("Invalid choice")
    
    board()
    i = checkWin()
    
    if i == 1:
        flag = 1
        break
    elif i == 0:
        flag = 1
    elif i == -1:
        flag = 0
        
    if player == 1:
        player = 2
    else:
        player = 1
    
    
board()

if (i == 1):
    print("Player",player, "win ")
elif(i == 0 ):
    print("Game draw");
# Out:
#  Tic Tac Toe Game
#
# 	0 1 2
#
# 	3 4 5
#
# 	6 7 8
#
# Player Number  1
# Enter the choice : 5
#
#  Tic Tac Toe Game
#
# 	0 1 2
#
# 	3 4 O
#
# 	6 7 8
#
# Player Number  2
# Enter the choice : 2
#
#  Tic Tac Toe Game
#
# 	0 1 X
#
# 	3 4 O
#
# 	6 7 8
#
# Player Number  1
# Enter the choice : 4
#
#  Tic Tac Toe Game
#
# 	0 1 X
#
# 	3 O O
#
# 	6 7 8
#
# Player Number  2
# Enter the choice : 8
#
#  Tic Tac Toe Game
#
# 	0 1 X
#
# 	3 O O
#
# 	6 7 X
#
# Player Number  1
# Enter the choice : 3
#
#  Tic Tac Toe Game
#
# 	0 1 X
#
# 	O O O
#
# 	6 7 X
#
#
#  Tic Tac Toe Game
#
# 	0 1 X
#
# 	O O O
#
# 	6 7 X
#
# Player 1 win
